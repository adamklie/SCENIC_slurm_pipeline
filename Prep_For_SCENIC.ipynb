# %% [markdown]
# # Notebook Title

# %% [markdown]
# **Authorship:**
# Author, *MM/DD/YYYY*
# ***
# **Description:**
# Notebook to do some cool stuff
# ***
# **TODOs:**
#  - <font color='green'> Done TODO </font>
#  - <font color='orange'> WIP TODO </font>
#  - <font color='red'> Queued TODO </font>
# ***

# %% [markdown]
# ## Set-up

# %%
# The classics
suppressMessages(library(Seurat))
suppressMessages(library(loomR))
suppressMessages(library(SeuratDisk))

# %% [markdown]
# ## Part 1
# Description

# %%
dat <- readRDS("/cellar/users/kivil/Data/Projects/runx1/output/rds/runx1_dox_regressed_LOFandWT.rds")

# %%
# RX1_117=WT, RX1_117=LOF
DimPlot(dat, reduction="umap", group.by="Genotype")
# Out:
# plot without title

# %%
loom.file <- as.loom(dat, filename = "runx1_dox_regressed_LOFandWT.loom", verbose = TRUE)
# Out:
# Saving data from RNA as /matrix
#
# Adding slot counts for assay RNA
#
# Adding layer counts
#
# Adding col attribute CellID
#
# Adding col attribute orig.ident
#
# Adding col attribute nCount_RNA
#
# Adding col attribute nFeature_RNA
#
# Adding col attribute nCount_Custom
#
# Adding col attribute nFeature_Custom
#
# Adding col attribute Genotype
#
# Adding col attribute Condition
#
# Adding col attribute Mutation
#
# Adding col attribute Group
#
# Adding col attribute Network
#
# Adding col attribute Disease
#
# Adding col attribute percent.mt
#
# Adding col attribute S.Score
#
# Adding col attribute G2M.Score
#
# Adding col attribute Phase
#
# Adding col attribute RNA_snn_res.0.05
#
# Adding col attribute seurat_clusters
#
# Adding col attribute RNA_snn_res.0.4
#
# Adding row attribute Gene

# %%
loom.file$close_all()

# %% [markdown]
# ## Part 2
# Description

# %% [markdown]
# # Scratch
# Place for old or testing code

# %% [markdown]
# # References
